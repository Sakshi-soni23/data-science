# %%
import pandas as pd
df =pd.read_excel("Data cleaning.xlsx")
df
# Out:
#             Name  Age  Gender        City                     Email  \
# 0    Sakshi Soni   23  Female      Indore   sakshi.soni@example.com
# 1    Aniket Soni   25    Male        Dhar   aniket.soni@example.com
# 2    Priya Mehta   22  Female      Mumbai   priya.mehta@example.com
# 3    Priya Mehta   22  Female      Mumbai   priya.mehta@example.com
# 4     Neha Verma   28  Female      Jaipur                       NaN
# 5    Aarav Patel   24    Male   Ahmedabad   aarav.patel@example.com
# 6      Riya Jain   21  Female         NaN     riya.jain@example.com
# 7    Mohit Gupta   27    Male        Pune   mohit.gupta@example.com
# 8   Tanya Kapoor   26  Female  Chandigarh  tanya.kapoor@example.com
# 9     Aditya Rao   29    Male   Bengaluru    aditya.rao@example.com
# 10   Mohit Gupta   27    Male        Pune   mohit.gupta@example.com
# 11   Aarav Patel   24    Male   Ahmedabad   aarav.patel@example.com
#
#    Joining Date
# 0    2021-05-14
# 1    2020-03-21
# 2           NaT
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#            Name  Age  Gender        City                     Email  \
# 0   Sakshi Soni   23  Female      Indore   sakshi.soni@example.com
# 1   Aniket Soni   25    Male        Dhar   aniket.soni@example.com
# 2   Priya Mehta   22  Female      Mumbai   priya.mehta@example.com
# 4    Neha Verma   28  Female      Jaipur                       NaN
# 5   Aarav Patel   24    Male   Ahmedabad   aarav.patel@example.com
# 6     Riya Jain   21  Female         NaN     riya.jain@example.com
# 7   Mohit Gupta   27    Male        Pune   mohit.gupta@example.com
# 8  Tanya Kapoor   26  Female  Chandigarh  tanya.kapoor@example.com
# 9    Aditya Rao   29    Male   Bengaluru    aditya.rao@example.com
#
#   Joining Date
# 0   2021-05-14
# 1   2020-03-21
# 2          NaT
# 4   2019-11-04
# 5   2023-01-17
# 6   2021-09-05
# 7   2020-12-23
# 8          NaT
# 9   2018-06-30
